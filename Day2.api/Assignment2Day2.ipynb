# %% [markdown]
# 1.Back slash

# %%
print("Hello\
 python")
# Out:
# Hello python

# %% [markdown]
# 2.Tripple Quote

# %%
print("""Hello Everyone""")
# Out:
# Hello Everyone

# %%
"""Hey"""
# Out:
# 'Hey'

# %% [markdown]
# 3.String inside the quote

# %%
print("How are you all?")
# Out:
# How are you all?

# %%
print("Pthon's World")
# Out:
# Pthon's World

# %%
print('Python\'s World!!')
# Out:
# Python's World!!

# %% [markdown]
# 4.Escape sequence

# %%
print("Hey all \t Whats happening here?")
# Out:
# Hey all 	 Whats happening here?

# %%
print("Hey all \n Whats happening here?")
# Out:
# Hey all
#  Whats happening here?

# %%
name="Dhanashree"
age="22"
favourite_subject="Maths"
print("The name of person is",name,",age is",age,"and favourite subject is",favourite_subject)
# Out:
# THe name of person is Dhanashree ,age is 22 and favourite subject is Maths

# %%
print("The name of person is %s and favourite subject is %s"%(name,favourite_subject))
# Out:
# The name of person is Dhanashree and favourite subject is Maths

# %%
print(f"The name of person is {name},age is {age} and favourite subject is {favourite_subject}")
# Out:
# The name of person is Dhanashree,age is 22 and favourite subject is Maths

# %% [markdown]
# Variables

# %%
a=100;
a
# Out:
# 100

# %%
x=y=333;
x
# Out:
# 333

# %%
y
# Out:
# 333

# %%
id(x)
# Out:
# 140678233922032

# %%
id(y)
# Out:
# 140678233922032

# %%
del x

# %%
Operators

# %%
a=1
b=2
a+b
# Out:
# 3

# %%
a=20
b=30
a-b
# Out:
# -10

# %%
a*b
# Out:
# 600

# %%
a/b
# Out:
# 0.6666666666666666

# %%
a**b
# Out:
# 1073741824000000000000000000000000000000

# %% [markdown]
# Comparison Opeartors

# %%
a=22
b=33
a==b
# Out:
# False

# %%
c=22
a==c
# Out:
# True

# %%
c<a
# Out:
# False

# %%
c<=a
# Out:
# True

# %%
b>=a
# Out:
# True

# %%
a!=b
# Out:
# True

# %%
not a!=c
# Out:
# True

# %%
Bitwise Operator

# %%
a=240
b=1
bin(a)
# Out:
# '0b11110000'

# %%
bin(b)
# Out:
# '0b1'

# %%
a&b
# Out:
# 0

# %%
Logical Operator

# %%
a=10
b=20
a>20
# Out:
# False

# %%
a>20 or 10>9
# Out:
# True

# %%
a>20 and 10>9
# Out:
# False

# %%
10<9 and 20>M
# Out:
# False

# %%
not 10<9
# Out:
# True

# %% [markdown]
# Membership Operator

# %%
str1="Am I getting Bore?"
"e"in str1
# Out:
# True

# %%
"z" in str1
# Out:
# False

# %% [markdown]
# Identity Operator

# %%
a=10
b=10
a==b
# Out:
# True

# %%
a is b
# Out:
# True

# %%
id(a)
# Out:
# 10914784

# %%
id(b)
# Out:
# 10914784

# %%
x=11.5
y=11.5
x==y
# Out:
# True

# %%
x is y
# Out:
# False

# %%
10+10/20*4
# Out:
# 12.0

# %%
2**-1
# Out:
# 0.5

# %% [markdown]
#  Extra Floar Division

# %%
7/3
# Out:
# 2.3333333333333335

# %%
7//3
# Out:
# 2

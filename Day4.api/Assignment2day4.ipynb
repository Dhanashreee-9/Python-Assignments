# %%
str2="What we think we become; we are python programmers."
str2.islower()
# Out:
# False

# %%
str2.isupper()
# Out:
# False

# %%
str2.upper()
# Out:
# 'WHAT WE THINK WE BECOME; WE ARE PYTHON PROGRAMMERS.'

# %%
str2.lower()
# Out:
# 'what we think we become; we are python programmers.'

# %%
#Bacause it contains the original string it wont replace by new.
str2.islower()
# Out:
# False

# %%
str3=input("Enter any string:")
if(str3.islower()):
  print("Enetered string lower:",str3)
elif(str3.isupper()):
      print("Entered string upper:",str3)
else:
        print("Not VAlid",str3)
# Out:
# Enter any string:stAAAS
# Not VAlid stAAAS

# %%
str4="HELLO PYTHON"
str4.isupper()
# Out:
# True

# %%
str5="i am glad"
str5.islower()
# Out:
# True
